# %% [markdown]
# # 💎 Análise Exploratória de Dados (EDA) de Diamantes
#
# **Autor:** Jéssica Oliveira
#
# Este projeto realiza uma Análise Exploratória de Dados (EDA) no famoso conjunto de dados de diamantes do Kaggle, que contém atributos como `carat` (peso), `cut` (corte), `color` (cor), `clarity` (clareza) e `price` (preço). O objetivo é entender a distribuição das variáveis, identificar correlações e determinar os principais fatores que influenciam o preço de um diamante.
#
# ---
#
# ## 🛠️ Configuração e Carregamento de Bibliotecas
#
# Importação das bibliotecas essenciais para manipulação de dados (`pandas`, `numpy`) e visualização (`matplotlib`, `seaborn`).

# %%
# !pip install pandas
# !pip install matplotlib
# !pip install seaborn
# !pip install numpy

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np # Importa a biblioteca para manipulação matemática, como logaritmo

# %%
# 1. Carregar os dados (ajuste o nome do arquivo, se necessário)
df = pd.read_csv('diamonds.csv')

# %%
print(df.shape)

# %% [markdown]
# ## 🧹 Tratamento e Limpeza de Dados
#
# O conjunto de dados, embora limpo, contém algumas entradas inválidas, onde as dimensões (`x`, `y`, `z`) ou o `price` são registrados como **zero**. Essas entradas são fisicamente impossíveis e devem ser removidas para evitar distorções nas estatísticas e visualizações.
#
# **Atenção:** Removemos **20** linhas do DataFrame.

# %%
# Remover linhas onde 'price' ou as dimensões (x, y, z) são zero.
# Diamantes não podem ter preço ou dimensões zero.
df = df.drop(df[ (df["x"]==0) | (df["y"]==0) | (df["z"]==0) | (df["price"]==0) ].index, axis=0)

# %%
print(df.shape)

# %% [markdown]
# ## 📊 Análise da Distribuição de Variáveis Numéricas
#
# Variáveis como o peso (`carat`) e o preço (`price`) são cruciais. Analisar sua distribuição é o primeiro passo para entender sua natureza.
#
# ### Distribuição de `Carat` (Peso)
# O histograma revela uma **forte assimetria positiva**, com a maioria dos diamantes concentrada em pesos menores.
#
# ### Distribuição de `Price` (Preço)
# Devido à assimetria exponencial do preço, aplicamos a **transformação logarítmica** (`np.log(price)`) para visualizar a distribuição de forma mais normalizada.

# %%
plt.figure(figsize=(10, 6))
# kde=True: Adiciona a linha de densidade para suavizar o gráfico.
sns.histplot(df['carat'], bins=50, kde=True, color='skyblue') 
plt.title('Distribuição do Peso do Diamante (Carat)')
plt.xlabel('Carat')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# 1. 🔍 Assimetria Positiva (Skewness)
#
# A barra mais alta está localizada à extrema esquerda do gráfico (perto de $0$ Carat), e a cauda do gráfico se estende por um longo caminho para a direita (até $5$ Carat).
# Interpretação: A distribuição é fortemente assimétrica à direita (Positive Skew). A grande maioria dos diamantes no dataset possui um peso baixo (abaixo de $1.0$ Carat). Diamantes com peso mais alto ($2.0$ Carat ou mais) são raros. Isso é o que se espera do mercado de diamantes.
#
# 2. ⛰️ Picos (Modas) da Distribuição
#
# O gráfico não é suave, mas tem picos distintos, além do pico principal. Há picos claros próximos a $0.3$ Carat, $0.7$ Carat e, de forma mais acentuada, em torno de $1.0$ Carat e $1.5$ Carat.
# Interpretação: Estes picos representam as modas ou as frequências mais altas de pesos específicos. Os picos em números "arredondados" como $1.0$ e $1.5$ Carat sugerem uma tendência de corte e comércio. Os lapidadores de diamantes frequentemente buscam manter ou alcançar esses pesos inteiros ou semi-inteiros, pois eles são conhecidos como "pesos mágicos" e têm um valor de mercado desproporcionalmente maior.
#
# 3. 📉 Densidade da Curva (KDE Plot)
#
# A linha azul suave (KDE) segue a forma do histograma e cai abruptamente após o pico inicial.
# Interpretação: A frequência de ocorrência de diamantes de alto peso diminui rapidamente. Quanto maior o diamante, mais raro ele é. Se o seu modelo de precificação for sensível à frequência, ele deve ser robusto o suficiente para lidar com a raridade dos dados de alto carat.Em resumo, o gráfico mostra que o peso (Carat) é uma variável não-normal (altamente assimétrica), e qualquer análise estatística (como regressão) que dependa da normalidade provavelmente se beneficiará da transformação logarítmica do Carat (assim como do Price), para tornar a distribuição mais manejável.

# %%
plt.figure(figsize=(10, 6))
# np.log(df['price']) : Aplica o logaritmo natural (log) a todos os preços.
sns.histplot(np.log(df['price']), bins=50, kde=True, color='purple') 
plt.title('Distribuição do Preço (Transformação Logarítmica)')
plt.xlabel('Log do Preço')
plt.ylabel('Frequência')
plt.show()

# %% [markdown]
# 1. 🔬 Motivo da Transformação Logarítmica
#
# A transformação (Log do Preço) é usada para normalizar a distribuição. O resultado mostra que a distribuição agora está muito mais uniforme, o que é ideal para técnicas estatísticas como a Regressão Linear, que pressupõem uma distribuição normal  dos erros.
#
# 2. ⛰️ Natureza Bimodal (Dois Picos)
#
# A curva de densidade roxa (KDE) e as barras mostram claramente dois picos principais (bimodal).
# Primeiro Pico: Concentrado em torno de $6.5$ a $7.0$ (o que corresponde a preços mais baixos).
# Segundo Pico: Concentrado em torno de $8.0$ a $8.5$ (o que corresponde a preços mais altos).
# Interpretação: Esta distribuição sugere que o conjunto de dados pode ser composto por duas populações distintas de diamantes. Primeira População (Pico Esquerdo): Provavelmente a maioria dos diamantes menores (baixo carat), que são cortados e vendidos em massa. Segunda População (Pico Direito): Provavelmente diamantes maiores ou de alta qualidade (alto carat e/ou excelente cut/clarity), que representam um prêmio de mercado.
#
# 3. 📉 Assimetria Residual
#
# Mesmo após a transformação logarítmica, a distribuição não é uma curva normal perfeita. A cauda da distribuição se estende ligeiramente mais à direita (preços mais altos no logaritmo) do que à esquerda.
# Interpretação: O preço do diamante ainda tem uma leve assimetria positiva residual. Isso reforça a ideia de que os preços mais altos (diamantes grandes ou de qualidade excepcional) são mais difíceis de prever e representam uma variação maior no mercado.Em resumo, este gráfico indica que a variável preço está pronta para uso em modelos de regressão, mas o comportamento bimodal sugere que um modelo preditivo pode se beneficiar ao considerar o Carat (peso) como uma variável de segmentação para lidar com essas duas populações de preços distintas.

# %% [markdown]
# ## 🎨 Análise das Variáveis Categóricas e sua Relação com o Preço
#
# As variáveis categóricas (`cut`, `color`, `clarity`) definem a qualidade e são avaliadas para entender seu impacto no valor final.
#
# ### Frequência de Qualidade de Corte (`Cut`)
# O gráfico de barras (`Count Plot`) mostra a contagem de diamantes em cada categoria de corte.
#
# ### Impacto da Clareza (`Clarity`) no Preço
# O `Box Plot` é ideal para comparar a distribuição de preços em diferentes grupos de clareza, revelando a **mediana** e a **dispersão** de preço para cada nível de qualidade.

# %%
plt.figure(figsize=(8, 5))
# order=df['cut'].value_counts().index: Garante que as barras estejam ordenadas pela contagem.
sns.countplot(x='cut', data=df, order=df['cut'].value_counts().index, palette='viridis')
plt.title('Contagem de Diamantes por Qualidade de Corte')
plt.xlabel('Corte')
plt.ylabel('Contagem')
plt.show()

# %% [markdown]
# 1. 🥇 Predominância da Alta Qualidade
#
# As barras para as categorias "Ideal" (aproximadamente $21.500$ diamantes) e "Premium" (aproximadamente $13.500$ diamantes) são significativamente mais altas do que as demais.
# Interpretação: A maioria dos diamantes no seu conjunto de dados possui a mais alta qualidade de corte. Isso sugere que a qualidade de corte é extremamente valorizada, e que cortes inferiores (como "Good" e "Fair") são muito menos comuns neste dataset específico. Isso pode refletir a demanda do mercado por diamantes bem lapidados ou a forma como o dataset foi coletado (focando em varejo de alta qualidade).
#
# 2. 📉 Rara Ocorrência de Baixa Qualidade
#
#
# A contagem cai drasticamente para "Good" (cerca de $5.000$) e, especialmente, para "Fair" (menos de $2.000$).
# Interpretação: As categorias de corte "Good" e "Fair" são as mais raras no seu conjunto de dados. Para fins de modelagem preditiva, você deve ter cuidado ao prever o preço de um diamante com corte "Fair" ou "Good", pois o modelo terá menos dados de treinamento nessas categorias. Embora o preço tenda a ser mais baixo, a falta de amostras pode tornar a previsão menos precisa ou menos robusta para esses casos.
#
# 3. Ordem da Qualidade
#
# As categorias estão naturalmente ordenadas da esquerda (Melhor: Ideal) para a direita (Pior: Fair).
# Interpretação: A contagem geralmente diminui à medida que a qualidade do corte diminui (com exceção de "Premium" sendo ligeiramente menos comum que "Ideal", mas ainda assim à frente de "Very Good"). Isso reforça o entendimento de que a prioridade na indústria é a lapidação de alta precisão.
# Em resumo, o gráfico confirma que o seu dataset é enviesado para a alta qualidade de corte, o que é um ponto importante a ser notado ao analisar o impacto de outras variáveis no preço.

# %%
plt.figure(figsize=(10, 6))
# Box plot: Ideal para comparar a distribuição de uma variável numérica (y) em categorias (x).
sns.boxplot(x='clarity', y='price', data=df, 
            order=['I1', 'SI2', 'SI1', 'VS2', 'VS1', 'VVS2', 'VVS1', 'IF'], palette='Blues')
plt.title('Distribuição de Preços por Clareza')
plt.xlabel('Clareza')
plt.ylabel('Preço (USD)')
plt.show()

# %% [markdown]
# 1. 📏 O Efeito Contraintuitivo da Clareza
#
# Observando a linha central (mediana) de cada caixa:As categorias de clareza mais baixa (I1, SI2, SI1) têm medianas de preço (linha central da caixa) mais altas do que as categorias de clareza muito alta (VVS2, VVS1, IF).
# Interpretação: A mediana do preço não aumenta consistentemente com a melhoria da clareza. Este padrão ocorre porque a variável dominante, o peso (Carat), está mascarando o efeito da clareza.Diamantes grandes (alto Carat) são caros, mesmo que tenham uma clareza média ou baixa.Diamantes pequenos (baixo Carat) podem ter clareza perfeita (IF), mas seu preço base é muito baixo.Portanto, a população de diamantes grandes e de clareza média/baixa está elevando a mediana das categorias I1 a SI1.
#
# 2. 📉 Dispersão e Concentração de Preços
#
# O tamanho das caixas e a posição das caixas na vertical.A caixa para SI2 e VS2 parece ser uma das maiores.As caixas para VVS1 e IF (clareza perfeita) estão localizadas mais abaixo no gráfico.Interpretação: A variabilidade de preço (tamanho da caixa) é maior nas categorias de clareza média (SI2, VS2).Significado: Isso sugere que a maioria dos diamantes negociados tem clareza média, o que significa que há uma maior mistura de pesos e outros atributos nessas caixas. Já os diamantes de clareza perfeita (IF) tendem a ser mais uniformemente pequenos e caros, mas o preço máximo é limitado.
#
# 3. ⚪ Outliers (Pontos Extremos)
#
# Muitos pontos pretos (círculos) no topo das "hastes" em todas as categorias.
# Interpretação: Todas as categorias possuem outliers (valores atípicos de preço).Significado: Os diamantes mais caros ($17.500$ USD e acima) aparecem em todas as categorias de clareza. Esses outliers representam os diamantes mais raros — geralmente aqueles que combinam um peso (Carat) muito alto com uma clareza aceitável.Em resumo, este Box Plot nos ensina que, isoladamente, a clareza não é o fator de maior peso no preço; o preço é uma função multiplicativa do Carat e das variáveis de qualidade.

# %% [markdown]
# ## 🔗 Análise de Relações e Correlações
#
# Esta é a etapa onde identificamos a relação entre as variáveis, crucial para a futura modelagem de preços.
#
# ### Correlação Carat vs. Price
# O `Scatter Plot` mostra uma **correlação positiva muito forte** e não linear, confirmando que o peso é o principal fator de precificação. A transparência (`alpha`) foi usada para visualizar a densidade de pontos.
#
# ### Mapa de Calor da Correlação (Heatmap)
# A matriz de correlação quantifica a relação entre todas as variáveis numéricas, destacando a alta correlação entre o `carat` e as dimensões (`x`, `y`, `z`).

# %%
plt.figure(figsize=(10, 6))
# alpha=0.1: Define a transparência dos pontos. Útil para datasets grandes!
sns.scatterplot(x='carat', y='price', data=df, alpha=0.1, color='darkred')
plt.title('Correlação entre Preço e Peso (Carat)')
plt.xlabel('Carat')
plt.ylabel('Preço (USD)')
plt.show()

# %% [markdown]
# 1. 🔗 Correlação Positiva e Não Linear
#
# Os pontos formam uma nuvem que se move de forma consistente para cima e para a direita. A relação inicial é apertada e depois se alarga.
# Interpretação: Existe uma correlação positiva muito forte entre Carat e Price. Quanto maior o peso do diamante, maior é o seu preço. A curva é exponencial (não linear), o que significa que o aumento de preço por unidade de peso é maior para diamantes mais pesados (acima de $1.0$ Carat).
#
# 2. 🎚️ Pontos de Salto de Preço
#
# Há bandas verticais de alta densidade (pontos agrupados) que aparecem em pesos específicos, notavelmente em $1.0$ Carat, $1.5$ Carat e $2.0$ Carat.Interpretação: Estes são os "pesos mágicos" do mercado. Diamantes que cruzam um peso-chave (como passar de $0.99$ para $1.00$ Carat) experimentam um salto desproporcional no preço, mesmo que a diferença de peso seja mínima. Os vendedores cobram um prêmio por atingir esses marcos.
#
# 3. ☁️ Aumento da Variância (Dispersão)
#
# A nuvem de pontos é muito estreita para diamantes abaixo de $1.0$ Carat. Acima de $1.0$ Carat, a nuvem de pontos se alarga verticalmente (mais dispersão).Interpretação: A variância (dispersão) do preço aumenta drasticamente com o peso. Para diamantes pequenos, há pouca diferença de preço entre qualidades (o preço é determinado principalmente pelo Carat).Para diamantes grandes (acima de $1.0$ Carat), a diferença de preço entre um diamante de corte "Fair" e um de corte "Ideal" é enorme, causando grande dispersão vertical. As outras variáveis de qualidade (Cut, Clarity, Color) têm seu maior impacto no preço de diamantes mais pesados.Em resumo, o gráfico prova que o Carat é o principal driver de preço, mas que a qualidade (as outras variáveis) é o que define a dispersão e o prêmio de preço nos pesos mais altos.

# %%
# Selecionar variáveis numéricas para a matriz de correlação
corr_matrix = df[['carat', 'depth', 'table', 'price', 'x', 'y', 'z']].corr() 

plt.figure(figsize=(8, 7))
# annot=True: Mostra o valor da correlação na célula.
# cmap='coolwarm': Define o esquema de cores.
sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt=".2f")
plt.title('Mapa de Calor da Correlação entre Variáveis Numéricas')
plt.show()

# %% [markdown]
# 1. 🥇 Relação Principal: Preço e Peso (price e carat)
#
# A correlação entre price e carat é $0.92$ (célula vermelha escura).
# Interpretação: Esta é uma correlação positiva extremamente forte. Confirma que o peso (carat) é o principal fator que impulsiona o preço (price) do diamante. Se o peso aumenta, o preço aumenta de forma previsível.
#
# 2. 📏 Relação entre Peso e Dimensões
#
# O carat apresenta correlações quase perfeitas com as dimensões (x, y, z):carat vs. x (comprimento): $0.98$carat vs. y (largura): $0.95$carat vs. z (profundidade): $0.96$Interpretação: Isso é esperado e lógico. Diamantes mais pesados são, naturalmente, fisicamente maiores. Essas dimensões estão tão altamente correlacionadas com carat que você pode considerar que elas contêm informações redundantes. Em modelos preditivos, incluir carat e as três dimensões pode levar à multicolinearidade (variáveis que medem quase a mesma coisa).
#
# 3. 🎯 Impacto das Métricas de Corte
#
# O price tem correlações muito baixas com depth (profundidade) e table (mesa):price vs. depth: $-0.01$ (Quase zero)price vs. table: $0.13$ (Fraca positiva)Interpretação: Essas métricas geométricas do corte não têm um forte impacto linear no preço. O price é dominado pelo carat. Embora um bom depth e table sejam importantes para a qualidade (que é capturada pelas variáveis categóricas cut e clarity), o efeito direto e linear dessas dimensões no preço é mínimo em comparação com o peso.
#
# 4. 🔀 Correlação Negativa (depth e table)
#
# A correlação entre depth e table é $-0.30$ (célula azul).Interpretação: Esta é uma correlação negativa fraca a moderada. Isso sugere que, em geral, se um diamante tem uma profundidade (depth) maior, ele tende a ter uma mesa (table) menor, e vice-versa. Isso reflete um compromisso comum no processo de lapidação para otimizar o peso ou o brilho.Em resumo, este mapa de calor prova numericamente o que o Scatter Plot sugeriu: o carat é de longe o fator mais importante para o preço. As outras variáveis de dimensão e corte são secundárias ou redundantes.

# %% [markdown]
# ## ✅ Conclusão e Resumo dos Insights
#
# Esta Análise Exploratória de Dados (EDA) forneceu evidências visuais e numéricas para os fatores que influenciam o preço dos diamantes:
#
# 1.  **O Peso é o Rei:** A correlação fortíssima entre **`carat` e `price` ($\mathbf{0.92}$)** prova que ele é o principal *driver* de preço, superando todos os outros fatores lineares.
# 2.  **Prêmio de Qualidade no Alto Carat:** As variáveis de qualidade (`cut`, `clarity`, `color`) têm seu maior impacto e causam maior dispersão de preço em diamantes mais pesados (acima de 1.0 Carat).
# 3.  **Preparação para Modelagem:** A transformação logarítmica no preço e a identificação de variáveis altamente correlacionadas (como as dimensões `x, y, z`) são passos essenciais para a construção de um modelo de regressão preciso.
